# %%
import pandas as pd

# %%
file_dir = 'C://Users//Mubeen Ahmed Khan//Desktop//Git//RBC-Module-8-ETL-Extract-Transform-Load-Git-Ready//the-movies-dataset'
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 31095  False                   NaN         0
# 2970   False                   NaN         0
# 19199  False                   NaN         0
# 5274   False                   NaN         0
# 1165   False                   NaN  31500000
#
#                                                   genres  \
# 31095                     [{'id': 35, 'name': 'Comedy'}]
# 2970   [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 19199                     [{'id': 35, 'name': 'Comedy'}]
# 5274                       [{'id': 18, 'name': 'Drama'}]
# 1165   [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
#
#                               homepage     id    imdb_id original_language  \
# 31095                              NaN  49398  tt0083824                fr
# 2970                               NaN   9647  tt0096061                en
# 19199  http://www.bobfunkthemovie.com/  19575  tt1091172                en
# 5274                               NaN  41165  tt0158033                en
# 1165      http://www.apocalypsenow.com     28  tt0078788                en
#
#                                       original_title  \
# 31095  Deux heures moins le quart avant Jésus-Christ
# 2970                                        Scrooged
# 19199                                       Bob Funk
# 5274                                            Nora
# 1165                                  Apocalypse Now
#
#                                                 overview  ... release_date  \
# 31095  In antique Rome, a simple pepboy for chars bec...  ...   1982-10-05
# 2970   In this modern take on Charles Dickens' "A Chr...  ...   1988-11-22
# 19199  After he's fired from his job -- by his mother...  ...   2009-03-20
# 5274   In 1904, in Dublin, James Joyce chats up Nora ...  ...   2000-04-05
# 1165   At the height of the Vietnam war, Captain Benj...  ...   1979-08-15
#
#           revenue runtime                                   spoken_languages  \
# 31095         0.0   110.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 2970   60328000.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19199         0.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5274          0.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1165   89460381.0   153.0  [{'iso_639_1': 'km', 'name': ''}, {'iso_639_1'...
#
#          status                                            tagline  \
# 31095  Released                                                NaN
# 2970   Released  The spirits will move you in odd and hysterica...
# 19199  Released                              Welcome To My Decline
# 5274   Released                                                NaN
# 1165   Released                                 This is the end...
#
#                                     title  video vote_average vote_count
# 31095  Quarter to Two Before Jesus Christ  False          6.3       26.0
# 2970                             Scrooged  False          6.7      395.0
# 19199                            Bob Funk  False          5.0        6.0
# 5274                                 Nora  False          6.1        6.0
# 1165                       Apocalypse Now  False          8.0     2112.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 13286745  138123      371     3.0   965627940
# 3865751    40222      337     3.0  1419807459
# 25010957  260168     3793     4.5  1447386936
# 7628099    78809     1968     3.0   942776640
# 3894794    40465   145140     3.5  1457316156
